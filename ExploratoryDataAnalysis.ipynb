# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabhpsd/Main1/blob/main/ExploratoryDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Univariate Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('iris.csv')
df.head()

df.shape
df_setosa = df.loc[df['variety'] == 'Setosa']
df_virginica = df.loc[df['variety'] == 'Virginica']
df_versicolor = df.loc[df['variety'] == 'Versicolor']

plt.plot(df_setosa['sepal.length'], np.zeros_like(df_setosa['sepal.length']))
plt.plot(df_virginica['sepal.length'], np.zeros_like(df_virginica['sepal.length']))
plt.plot(df_versicolor['sepal.length'], np.zeros_like(df_versicolor['sepal.length']))

plt.xlabel('petal.lenght')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.FacetGrid(df,hue = 'variety', size = 5).map(plt.scatter,"sepal.length","sepal.width").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df, hue = "variety", size = 3)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
